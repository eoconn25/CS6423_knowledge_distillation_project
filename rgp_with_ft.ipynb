# %% [markdown]
# Rigours Iterative Pruning: With Fine Tuning
# - This is the verison of RPG that includes finetuning, as it as part of gradation to recover the accuracy
# - A point was made to not include it to match other models more, two files were made to maintain the results for each
# - There is a sperate file that does the same steps without finetuning (gradation_pruning_withoutFT.ipynb)
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# Rough Overview of results
# ![Screenshot 2026-03-12 at 10.11.31.png](attachment:7b43ef3b-7e48-49f9-80ff-5edce4a992d3.png)
# - The F1 scores were able to recover with a slight drop at step 3
#     - Step 4 jumps back to 1 -> unsual
#     - Could mean DFOT scorer picked a less critical filters at step 4 or 1 epoch ecovery was enoguh
# - Baseline of F1 gets to 1 due to the 10 epochs, not fine tuning
# - The reason why the other F1 scores is so high is due to the small dataset size, could see more real results with a larger dataset
# - The latency saw a 21% reduction
# - The size saw a 46% reduction

# %%
import os, sys, copy
import torch
import torch.nn as nn
import pandas as pd
from tqdm.auto import tqdm
from collections import OrderedDict
from torchvision import models, transforms
from torch.utils.data import DataLoader, random_split

# navigate to project root
target = "CS6423_knowledge_distillation_project"
if not os.getcwd().endswith(target):
    os.chdir(os.path.join(os.getcwd(), target))
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

print(f"Working dir: {os.getcwd()}")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Working dir: /home/kod6/CS6423_knowledge_distillation_project
# Device: cuda

# %%
import sys
# !{sys.executable} -m pip install timm tabulate
from modules.dataset import radImageDataset
from modules.evaluate_model import ModelEvaluator
from modules.model_trainer import modelTrainer
print("radImageDataset, ModelEvaluator, modelTrainer imported")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: timm in /home/kod6/.local/lib/python3.13/site-packages (1.0.25)
# Requirement already satisfied: tabulate in /home/kod6/.local/lib/python3.13/site-packages (0.10.0)
# Requirement already satisfied: torch in /home/kod6/.local/lib/python3.13/site-packages (from timm) (2.10.0)
# Requirement already satisfied: torchvision in /home/kod6/.local/lib/python3.13/site-packages (from timm) (0.25.0)
# Requirement already satisfied: pyyaml in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from timm) (6.0.3)
# Requirement already satisfied: huggingface_hub in /home/kod6/.local/lib/python3.13/site-packages (from timm) (1.6.0)
# Requirement already satisfied: safetensors in /home/kod6/.local/lib/python3.13/site-packages (from timm) (0.7.0)
# Requirement already satisfied: filelock>=3.10.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from huggingface_hub->timm) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from huggingface_hub->timm) (2026.1.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in /home/kod6/.local/lib/python3.13/site-packages (from huggingface_hub->timm) (1.3.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from huggingface_hub->timm) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from huggingface_hub->timm) (25.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/kod6/.local/lib/python3.13/site-packages (from huggingface_hub->timm) (4.67.3)
# Requirement already satisfied: typer in /home/kod6/.local/lib/python3.13/site-packages (from huggingface_hub->timm) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from huggingface_hub->timm) (4.15.0)
# Requirement already satisfied: anyio in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (4.11.0)
# Requirement already satisfied: certifi in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (1.0.9)
# Requirement already satisfied: idna in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface_hub->timm) (3.11)
# Requirement already satisfied: h11>=0.16 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->timm) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub->timm) (1.3.1)
# Requirement already satisfied: setuptools in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from torch->timm) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from torch->timm) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from torch->timm) (3.6.1)
# Requirement already satisfied: jinja2 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/kod6/.local/lib/python3.13/site-packages (from torch->timm) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/kod6/.local/lib/python3.13/site-packages (from cuda-bindings==12.9.4->torch->timm) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from sympy>=1.13.3->torch->timm) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from jinja2->torch->timm) (3.0.3)
# Requirement already satisfied: numpy in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from torchvision->timm) (2.4.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from torchvision->timm) (12.0.0)
# Requirement already satisfied: click>=8.2.1 in /home/kod6/.local/lib/python3.13/site-packages (from typer->huggingface_hub->timm) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/kod6/.local/lib/python3.13/site-packages (from typer->huggingface_hub->timm) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from typer->huggingface_hub->timm) (14.2.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/kod6/.local/lib/python3.13/site-packages (from typer->huggingface_hub->timm) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from rich>=12.3.0->typer->huggingface_hub->timm) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from rich>=12.3.0->typer->huggingface_hub->timm) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /cm/ucc/miniconda3/miniconda3/envs/student/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->timm) (0.1.2)
# radImageDataset, ModelEvaluator, modelTrainer imported

# %%
#load data with radImageDataset
IMAGES_DIR = "data/test_images"
LABELS_CSV = "data/labels.csv"
BATCH_SIZE = 32

transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225]),
])

df = pd.read_csv(LABELS_CSV)
print(f"Labels CSV: {len(df)} rows, columns: {df.columns.tolist()}")
print(df.head(3))

# use the project's existing radImageDataset directly
full_dataset = radImageDataset(dataframe=df, image_dir=IMAGES_DIR, transform=transform)
CLASS_NAMES  = full_dataset.class_names
NUM_CLASSES  = len(CLASS_NAMES)
print(f"\nClasses: {NUM_CLASSES} | e.g. {list(CLASS_NAMES[:5])}")

# 80/20 train/val split
n_val   = max(1, int(0.2 * len(full_dataset)))
n_train = len(full_dataset) - n_val
train_set, val_set = random_split(
    full_dataset, [n_train, n_val],
    generator=torch.Generator().manual_seed(42)
)
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True,  num_workers=0, pin_memory=True)
val_loader   = DataLoader(val_set,   batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
print(f"Train: {len(train_set)} | Val: {len(val_set)}")
# Out:
# Labels CSV: 9000 rows, columns: ['filename', 'pathology', 'modality', 'location', 'label']
#      filename          pathology modality    location  \
# 0  test_0.png  flexor_pathology_      mri  ankle foot
# 1  test_1.png  flexor_pathology_      mri  ankle foot
# 2  test_2.png  flexor_pathology_      mri  ankle foot
#
#                           label
# 0  ankle_foot_flexor_pathology_
# 1  ankle_foot_flexor_pathology_
# 2  ankle_foot_flexor_pathology_
#
# Classes: 122 | e.g. ['abdomen_abnormal_entire_organ', 'abdomen_adrenal_pathology', 'abdomen_arterial_pathology', 'abdomen_ascites', 'abdomen_bil_dil']
# Train: 7200 | Val: 1800

# %%
# Load ResNet50 using ImagenetLoader with freeze_backbone
from modules.imagenet_loader import ImagenetLoader

WEIGHTS_PATH = "trained_models/resnet50_baseline/resnet50_baseline.pth"

loader = ImagenetLoader()
model = loader.load_radimagenet_resnet50(
    weights_path=WEIGHTS_PATH,
    load_type="load"   # loads weights into the 122-class head directly
)
loader.freeze_backbone()  # freeze everything except fc
model = model.to(device)

print(f"ResNet50 loaded via ImagenetLoader")
print(f"Total params: {sum(p.numel() for p in model.parameters()):,}")
print(f"Trainable params: {sum(p.numel() for p in model.parameters() if p.requires_grad):,}")
# Out:
# ResNet50 loaded via ImagenetLoader
# Total params: 23,758,010
# Trainable params: 249,978

# %%
# Train fc head only (backbone frozen) for 10 epochs
optimizer = torch.optim.Adam(
    [p for p in model.parameters() if p.requires_grad], lr=1e-3
)
criterion = nn.CrossEntropyLoss()

model.train()
for epoch in range(10):
    total_loss = 0.0
    for imgs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/10"):
        imgs, labels = imgs.to(device), labels.to(device)
        optimizer.zero_grad()
        loss = criterion(model(imgs), labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    print(f"  Epoch {epoch+1} | loss: {total_loss/len(train_loader):.4f}")

# Unfreeze everything for pruning
for param in model.parameters():
    param.requires_grad = True
print("fc trained, all layers unfrozen — ready for pruning")
# Out:
# Epoch 1/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 1 | loss: 0.2957
# Epoch 2/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 2 | loss: 0.2291
# Epoch 3/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 3 | loss: 0.1930
# Epoch 4/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 4 | loss: 0.1699
# Epoch 5/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 5 | loss: 0.1514
# Epoch 6/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 6 | loss: 0.1349
# Epoch 7/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 7 | loss: 0.1323
# Epoch 8/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 8 | loss: 0.1156
# Epoch 9/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 9 | loss: 0.1127
# Epoch 10/10:   0%|          | 0/225 [00:00<?, ?it/s]
#   Epoch 10 | loss: 0.1121
# fc trained, all layers unfrozen — ready for pruning

# %%
#baseline evalution using ModelEvaluator
evaluator = ModelEvaluator(data_loader=val_loader, class_names=CLASS_NAMES, device=str(device))
baseline_metrics = evaluator.evaluate_single(model, model_name="ResNet50_baseline")

BASELINE_F1 = baseline_metrics["f1_macro"]
print(f"\nBaseline F1 macro:  {baseline_metrics['f1_macro']:.4f}")
print(f"Baseline F1 micro:  {baseline_metrics['f1_micro']:.4f}")
print(f"Baseline latency:   {baseline_metrics['avg_latency_ms']:.2f} ms/sample")
print(f"Baseline size:      {baseline_metrics['model_size_mb']:.2f} MB")
# Out:
# Warming up ResNet50_baseline...
# Running inference...
#
# Baseline F1 macro:  0.9959
# Baseline F1 micro:  0.9928
# Baseline latency:   1.10 ms/sample
# Baseline size:      90.83 MB

# %%
#DFOT Scorer (part of paper)
class DFOTScorer:
    def __init__(self, model, alpha=0.5):
        self.model   = model
        self.alpha   = alpha
        self._hooks  = []
        self._bufs   = {}
        self._counts = {}

    def register_hooks(self):
        for name, module in self.model.named_modules():
            if isinstance(module, nn.Conv2d):
                h = module.weight.register_hook(self._make_hook(name, module))
                self._hooks.append(h)
                self._bufs[name]   = None
                self._counts[name] = 0

    def _make_hook(self, name, module):
        def hook(grad):
            with torch.no_grad():
                raw      = (module.weight.detach() * grad).abs().pow(self.alpha)
                f_scores = raw.view(raw.shape[0], -1).sum(dim=1)
                if self._bufs[name] is None:
                    self._bufs[name] = f_scores.clone()
                else:
                    self._bufs[name] += f_scores
                self._counts[name] += 1
        return hook

    def get_scores(self, normalize=True):
        scores = {}
        for name, buf in self._bufs.items():
            if buf is None:
                continue
            s = buf / max(self._counts[name], 1)
            if normalize:
                s = s / (s.mean() + 1e-8)
            scores[name] = s
        return scores

    def remove_hooks(self):
        for h in self._hooks:
            h.remove()
        self._hooks = []


def compute_dfot_scores(model, loader, device, criterion, alpha=0.5, n_batches=10):
    model.train()
    scorer = DFOTScorer(model, alpha=alpha)
    scorer.register_hooks()
    for i, (imgs, labels) in enumerate(loader):
        if i >= n_batches:
            break
        imgs, labels = imgs.to(device), labels.to(device)
        model.zero_grad()
        loss = criterion(model(imgs)[:, :NUM_CLASSES], labels)
        loss.backward()
    scores = scorer.get_scores(normalize=True)
    scorer.remove_hooks()
    model.zero_grad()
    return scores

print("DFOTScorer defined ")
# Out:
# DFOTScorer defined

# %%
#layer significance assement
def assess_layer_significance(model, val_loader, device, class_names, top_k=3):
    print("\n=== Layer Significance Assessment ===")
    ev       = ModelEvaluator(val_loader, class_names=class_names, device=str(device))
    base_f1  = ev.evaluate_single(model, "base")["f1_macro"]
    print(f"  Baseline F1: {base_f1:.4f}")

    results     = []
    conv_layers = [(n, m) for n, m in model.named_modules() if isinstance(m, nn.Conv2d)]

    for name, module in tqdm(conv_layers, desc="Significance scan"):
        h   = module.register_forward_hook(lambda mod, inp, out: torch.zeros_like(out))
        f1  = ev.evaluate_single(model, name)["f1_macro"]
        h.remove()
        results.append({"layer": name, "f1_zeroed": f1, "f1_drop": base_f1 - f1})

    df        = pd.DataFrame(results).sort_values("f1_drop", ascending=False)
    df.to_csv("layer_significance.csv", index=False)
    protected = df.head(top_k)["layer"].tolist()

    print(f"\n  Protecting top-{top_k} layers:")
    for p in protected:
        row = df[df["layer"] == p].iloc[0]
        print(f"    {p}  (F1 drop={row['f1_drop']:.4f})")
    return protected, df

protected_layers, sig_df = assess_layer_significance(
    model, val_loader, device, CLASS_NAMES, top_k=3
)
# Out:
# === Layer Significance Assessment ===
#
# Warming up base...
# Running inference...
#   Baseline F1: 0.9959
# Significance scan:   0%|          | 0/53 [00:00<?, ?it/s]
# Warming up conv1...
# Running inference...
#
# Warming up layer1.0.conv1...
# Running inference...
#
# Warming up layer1.0.conv2...
# Running inference...
#
# Warming up layer1.0.conv3...
# Running inference...
#
# Warming up layer1.0.downsample.0...
# Running inference...
#
# Warming up layer1.1.conv1...
# Running inference...
#
# Warming up layer1.1.conv2...
# Running inference...
#
# Warming up layer1.1.conv3...
# Running inference...
#
# Warming up layer1.2.conv1...
# Running inference...
#
# Warming up layer1.2.conv2...
# Running inference...
#
# Warming up layer1.2.conv3...
# Running inference...
#
# Warming up layer2.0.conv1...
# Running inference...
#
# Warming up layer2.0.conv2...
# Running inference...
#
# Warming up layer2.0.conv3...
# Running inference...
#
# Warming up layer2.0.downsample.0...
# Running inference...
#
# Warming up layer2.1.conv1...
# Running inference...
#
# Warming up layer2.1.conv2...
# Running inference...
#
# Warming up layer2.1.conv3...
# Running inference...
#
# Warming up layer2.2.conv1...
# Running inference...
#
# Warming up layer2.2.conv2...
# Running inference...
#
# Warming up layer2.2.conv3...
# Running inference...
#
# Warming up layer2.3.conv1...
# Running inference...
#
# Warming up layer2.3.conv2...
# Running inference...
#
# Warming up layer2.3.conv3...
# Running inference...
#
# Warming up layer3.0.conv1...
# Running inference...
#
# Warming up layer3.0.conv2...
# Running inference...
#
# Warming up layer3.0.conv3...
# Running inference...
#
# Warming up layer3.0.downsample.0...
# Running inference...
#
# Warming up layer3.1.conv1...
# Running inference...
#
# Warming up layer3.1.conv2...
# Running inference...
#
# Warming up layer3.1.conv3...
# Running inference...
#
# Warming up layer3.2.conv1...
# Running inference...
#
# Warming up layer3.2.conv2...
# Running inference...
#
# Warming up layer3.2.conv3...
# Running inference...
#
# Warming up layer3.3.conv1...
# Running inference...
#
# Warming up layer3.3.conv2...
# Running inference...
#
# Warming up layer3.3.conv3...
# Running inference...
#
# Warming up layer3.4.conv1...
# Running inference...
#
# Warming up layer3.4.conv2...
# Running inference...
#
# Warming up layer3.4.conv3...
# Running inference...
#
# Warming up layer3.5.conv1...
# Running inference...
#
# Warming up layer3.5.conv2...
# Running inference...
#
# Warming up layer3.5.conv3...
# Running inference...
#
# Warming up layer4.0.conv1...
# Running inference...
#
# Warming up layer4.0.conv2...
# Running inference...
#
# Warming up layer4.0.conv3...
# Running inference...
#
# Warming up layer4.0.downsample.0...
# Running inference...
#
# Warming up layer4.1.conv1...
# Running inference...
#
# Warming up layer4.1.conv2...
# Running inference...
#
# Warming up layer4.1.conv3...
# Running inference...
#
# Warming up layer4.2.conv1...
# Running inference...
#
# Warming up layer4.2.conv2...
# Running inference...
#
# Warming up layer4.2.conv3...
# Running inference...
#
#   Protecting top-3 layers:
#     layer1.0.conv1  (F1 drop=0.9940)
#     conv1  (F1 drop=0.9939)
#     layer1.0.downsample.0  (F1 drop=0.9939)

# %%
# Global mask registry
pruning_mask = {}

def get_filters_to_prune(scores, prune_ratio, protected_layers):
    all_entries = []
    for layer_name, filter_scores in scores.items():
        # skip conv3 and downsample — skip-coupled
        if any(x in layer_name for x in ["conv3", "downsample"]):
            continue
        if any(p == layer_name for p in protected_layers):
            continue
        already_pruned = pruning_mask.get(layer_name, [])
        for f_idx, score in enumerate(filter_scores.cpu().tolist()):
            if f_idx not in already_pruned:
                all_entries.append((score, layer_name, f_idx))

    all_entries.sort(key=lambda x: x[0])
    n_prune = int(len(all_entries) * prune_ratio)
    prune_map = {}
    for _, layer_name, f_idx in all_entries[:n_prune]:
        prune_map.setdefault(layer_name, []).append(f_idx)
    return prune_map, n_prune


def structured_prune(model, prune_map):

    def set_module(model, name, new_module):
        parts = name.split(".")
        parent = model
        for p in parts[:-1]:
            parent = getattr(parent, p)
        setattr(parent, parts[-1], new_module)

    def prune_conv_out(conv, keep):
        new = nn.Conv2d(conv.in_channels, len(keep), conv.kernel_size,
                        stride=conv.stride, padding=conv.padding,
                        bias=conv.bias is not None)
        with torch.no_grad():
            new.weight.copy_(conv.weight[keep])
            if conv.bias is not None:
                new.bias.copy_(conv.bias[keep])
        return new

    def prune_conv_in(conv, keep):
        new = nn.Conv2d(len(keep), conv.out_channels, conv.kernel_size,
                        stride=conv.stride, padding=conv.padding,
                        bias=conv.bias is not None)
        with torch.no_grad():
            new.weight.copy_(conv.weight[:, keep, :, :])
            if conv.bias is not None:
                new.bias.copy_(conv.bias)
        return new

    def prune_bn(bn, keep):
        new = nn.BatchNorm2d(len(keep))
        with torch.no_grad():
            new.weight.copy_(bn.weight[keep])
            new.bias.copy_(bn.bias[keep])
            new.running_mean.copy_(bn.running_mean[keep])
            new.running_var.copy_(bn.running_var[keep])
        return new

    def get_module(model, name):
        """Always fetch live from model — never use stale dict."""
        m = model
        for p in name.split("."):
            m = getattr(m, p)
        return m

    for layer_name, prune_indices in prune_map.items():
        # skip conv3 and downsample — skip-coupled
        if "conv3" in layer_name or "downsample" in layer_name:
            print(f"  Skipping {layer_name} — skip-coupled")
            continue

        try:
            conv = get_module(model, layer_name)
        except AttributeError:
            continue
        if not isinstance(conv, nn.Conv2d):
            continue

        keep = [i for i in range(conv.out_channels) if i not in prune_indices]
        if len(keep) == 0:
            print(f"  ⚠ Skipping {layer_name} — would remove all filters")
            continue

        print(f"  {layer_name}: {conv.out_channels} → {len(keep)} filters")

        # 1. prune conv output
        set_module(model, layer_name, prune_conv_out(conv, keep))

        # 2. prune corresponding BN
        if "conv1" in layer_name:
            bn_name = layer_name.replace("conv1", "bn1")
        elif "conv2" in layer_name:
            bn_name = layer_name.replace("conv2", "bn2")
        else:
            bn_name = None

        if bn_name:
            try:
                bn = get_module(model, bn_name)
                if isinstance(bn, nn.BatchNorm2d):
                    set_module(model, bn_name, prune_bn(bn, keep))
            except AttributeError:
                pass

        # 3. prune next layer's input channels
        parts = layer_name.split(".")
        
        if layer_name == "conv1":
            # stem conv1 feeds into layer1.0.conv1 main path
            try:
                next_conv = get_module(model, "layer1.0.conv1")
                if isinstance(next_conv, nn.Conv2d):
                    set_module(model, "layer1.0.conv1", prune_conv_in(next_conv, keep))
                    print(f"    → updated layer1.0.conv1 input channels")
            except AttributeError:
                pass

            # stem conv1 also feeds into layer1.0.downsample.0 skip path
            try:
                ds = get_module(model, "layer1.0.downsample.0")
                if isinstance(ds, nn.Conv2d):
                    set_module(model, "layer1.0.downsample.0", prune_conv_in(ds, keep))
                    print(f"    → updated layer1.0.downsample.0 input channels")
            except AttributeError:
                pass

        elif len(parts) == 3:
            layer_group = parts[0]      # e.g. layer1
            block_idx   = int(parts[1]) # e.g. 0
            conv_num    = parts[2]      # e.g. conv1 or conv2

            if conv_num == "conv1":
                # conv1 → conv2 within same block
                next_name = f"{layer_group}.{block_idx}.conv2"
            elif conv_num == "conv2":
                # conv2 → conv3 within same block
                next_name = f"{layer_group}.{block_idx}.conv3"
            else:
                next_name = None

            if next_name:
                try:
                    next_conv = get_module(model, next_name)
                    if isinstance(next_conv, nn.Conv2d):
                        set_module(model, next_name, prune_conv_in(next_conv, keep))
                        print(f"    → updated {next_name} input: → {len(keep)}")
                except AttributeError:
                    pass

        pruning_mask[layer_name] = prune_indices

    total = sum(len(v) for v in pruning_mask.values())
    print(f"  Total filters removed: {total}")
    return model


def get_conv_sparsity(model):
    total_removed = sum(len(v) for v in pruning_mask.values())
    return total_removed / 26496

print("Structured pruning helpers defined")
# Out:
# Structured pruning helpers defined

# %%
#fine tuning via modelTrainer
class _MinimalDataPrep:
    """Minimal shim so modelTrainer works without a full DataPrep object.
    modelTrainer only uses .train_loader, .val_loader, .class_names, .class_weights."""
    def __init__(self, train_loader, val_loader, class_names):
        self.train_loader  = train_loader
        self.val_loader    = val_loader
        self.class_names   = class_names
        self.class_weights = None


def finetune_with_trainer(model, train_loader, val_loader,
                           class_names, device, epochs=3, lr=1e-4):
    data_prep = _MinimalDataPrep(train_loader, val_loader, class_names)
    trainer   = modelTrainer(
        model=model, data_prep=data_prep, device=device,
        learn_rate=lr, num_epochs=epochs,
        model_name="rgp_finetune_temp"   # won't save during pruning loop
    )
    trainer.prepare_for_training()

    best_val_f1 = 0.0
    for epoch in range(epochs):
        train_loss, train_f1 = trainer.train_epoch(epoch)
        val_loss,   val_f1   = trainer.validate()
        best_val_f1 = max(best_val_f1, val_f1)
        print(f"  Epoch {epoch+1}/{epochs} | "
              f"train_loss={train_loss:.4f} train_f1={train_f1:.4f} | "
              f"val_loss={val_loss:.4f}   val_f1={val_f1:.4f}")
    return model, best_val_f1

print("Fine-tune wrapper defined")
# Out:
# Fine-tune wrapper defined

# %%
#full RGP Pipeline
def rgp_pipeline(
    model,
    train_loader, val_loader, device, class_names,
    pruning_schedule = [0.10, 0.20, 0.30, 0.40, 0.50],
    alpha            = 0.5,
    top_k_protect    = 1,
    finetune_epochs  = 1,
    finetune_lr      = 1e-4,
    n_calib_batches  = 10,
    save_dir         = "rgp_checkpoints",
    early_stop_drop  = 1.0,
):
    os.makedirs(save_dir, exist_ok=True)
    criterion = nn.CrossEntropyLoss()
    ev        = ModelEvaluator(val_loader, class_names=class_names, device=str(device))

    # baseline
    baseline     = ev.evaluate_single(model, "ResNet50_baseline")
    BASELINE_F1  = baseline["f1_macro"]
    print(f"\n{'='*60}")
    print(f"BASELINE  F1={BASELINE_F1:.4f}  "
          f"size={baseline['model_size_mb']:.1f}MB  "
          f"latency={baseline['avg_latency_ms']:.2f}ms")
    print(f"{'='*60}")

    # initial layer significance
    protected_layers, _ = assess_layer_significance(
        model, val_loader, device, class_names, top_k=top_k_protect
    )

    log, cumulative = [], 0.0

    for step, target in enumerate(pruning_schedule):
        print(f"\n{'='*60}")
        print(f"RGP STEP {step+1}/{len(pruning_schedule)} → target: {target*100:.0f}%")
        print(f"{'='*60}")

        incremental = max(0.0, target - cumulative)
        if incremental < 0.01:
            print("  Already at target — skipping.")
            continue
        cumulative = target

        # 1. DFOT scores
        print(f"  Computing DFOT scores (alpha={alpha})...")
        scores = compute_dfot_scores(model, train_loader, device, criterion,
                                     alpha=alpha, n_batches=n_calib_batches)

        # 2. Structured prune
        prune_map, n_prune = get_filters_to_prune(scores, incremental, protected_layers)
        model = structured_prune(model, prune_map)
        sparsity = get_conv_sparsity(model)
        print(f"  Sparsity: {sparsity*100:.1f}%")

        # 3. Fine-tune to recover accuracy
        model, _ = finetune_with_trainer(
            model, train_loader, val_loader, class_names, device,
            epochs=finetune_epochs, lr=finetune_lr
        )

        # 4. Full eval via ModelEvaluator
        step_metrics = ev.evaluate_single(model, f"ResNet50_rgp_step{step+1}")
        f1_drop      = BASELINE_F1 - step_metrics["f1_macro"]

        print(f"\n  ✓ F1={step_metrics['f1_macro']:.4f}  Δ={-f1_drop:+.4f}  "
              f"size={step_metrics['model_size_mb']:.1f}MB  "
              f"latency={step_metrics['avg_latency_ms']:.2f}ms  "
              f"sparsity={sparsity*100:.1f}%")

        log.append(dict(
            step=step+1, target_ratio=target, sparsity=sparsity,
            f1_macro=step_metrics["f1_macro"], f1_micro=step_metrics["f1_micro"],
            sensitivity=step_metrics["sensitivity"], f1_drop=f1_drop,
            latency_ms=step_metrics["avg_latency_ms"], size_mb=step_metrics["model_size_mb"],
        ))

        # save checkpoint
        ckpt_name = f"resnet50_rgp_step{step+1}_{int(target*100)}pct"
        ckpt_dir  = os.path.join(save_dir, ckpt_name)
        os.makedirs(ckpt_dir, exist_ok=True)
        torch.save(
            {"model": model.state_dict(), "epoch": step+1,
             "sparsity": sparsity, "f1_macro": step_metrics["f1_macro"]},
            os.path.join(ckpt_dir, f"{ckpt_name}.pth")
        )
        print(f"  Saved → {ckpt_dir}/{ckpt_name}.pth")

        # 5. Reassess layer significance
        print("  Reassessing layer significance...")
        protected_layers, _ = assess_layer_significance(
            model, val_loader, device, class_names, top_k=top_k_protect
        )

        if f1_drop > early_stop_drop:
            print(f"\n F1 drop {f1_drop:.4f} > threshold — stopping early.")
            break

    log_df = pd.DataFrame(log)
    log_df.to_csv(os.path.join(save_dir, "rgp_log.csv"), index=False)
    print(f"\n{'='*60}\nRGP COMPLETE\n{log_df.to_string(index=False)}\n{'='*60}")
    ev.display_summary()
    return model, log_df

print("rgp_pipeline defined")
# Out:
# rgp_pipeline defined

# %%
#run RGP
pruned_model, log_df = rgp_pipeline(
    model            = model,
    train_loader     = train_loader,
    val_loader       = val_loader,
    device           = device,
    class_names      = CLASS_NAMES,
    #pruning_schedule = [0.10, 0.10, 0.10, 0.10, 0.10],  # 10% incremental each step,
    pruning_schedule = [0.10, 0.20, 0.30, 0.40, 0.50],
    alpha            = 0.5,       # DFOT desensitization exponent — tune in Cell 12
    top_k_protect    = 1,
    finetune_epochs  = 1,         # increase to 5-10 for better recovery
    finetune_lr      = 1e-4,      # ~10x smaller than original training LR
    n_calib_batches  = 10,
    save_dir         = "rgp_checkpoints",
    early_stop_drop = 1.0,
)
# Out:
# Warming up ResNet50_baseline...
# Running inference...
#
# ============================================================
# BASELINE  F1=0.9959  size=90.8MB  latency=1.10ms
# ============================================================
#
# === Layer Significance Assessment ===
#
# Warming up base...
# Running inference...
#   Baseline F1: 0.9959
# Significance scan:   0%|          | 0/53 [00:00<?, ?it/s]
# Warming up conv1...
# Running inference...
#
# Warming up layer1.0.conv1...
# Running inference...
#
# Warming up layer1.0.conv2...
# Running inference...
#
# Warming up layer1.0.conv3...
# Running inference...
#
# Warming up layer1.0.downsample.0...
# Running inference...
#
# Warming up layer1.1.conv1...
# Running inference...
#
# Warming up layer1.1.conv2...
# Running inference...
#
# Warming up layer1.1.conv3...
# Running inference...
#
# Warming up layer1.2.conv1...
# Running inference...
#
# Warming up layer1.2.conv2...
# Running inference...
#
# Warming up layer1.2.conv3...
# Running inference...
#
# Warming up layer2.0.conv1...
# Running inference...
#
# Warming up layer2.0.conv2...
# Running inference...
#
# Warming up layer2.0.conv3...
# Running inference...
#
# Warming up layer2.0.downsample.0...
# Running inference...
#
# Warming up layer2.1.conv1...
# Running inference...
#
# Warming up layer2.1.conv2...
# Running inference...
#
# Warming up layer2.1.conv3...
# Running inference...
#
# Warming up layer2.2.conv1...
# Running inference...
#
# Warming up layer2.2.conv2...
# Running inference...
#
# Warming up layer2.2.conv3...
# Running inference...
#
# Warming up layer2.3.conv1...
# Running inference...
#
# Warming up layer2.3.conv2...
# Running inference...
#
# Warming up layer2.3.conv3...
# Running inference...
#
# Warming up layer3.0.conv1...
# Running inference...
#
# Warming up layer3.0.conv2...
# Running inference...
#
# Warming up layer3.0.conv3...
# Running inference...
#
# Warming up layer3.0.downsample.0...
# Running inference...
#
# Warming up layer3.1.conv1...
# Running inference...
#
# Warming up layer3.1.conv2...
# Running inference...
#
# Warming up layer3.1.conv3...
# Running inference...
#
# Warming up layer3.2.conv1...
# Running inference...
#
# Warming up layer3.2.conv2...
# Running inference...
#
# Warming up layer3.2.conv3...
# Running inference...
#
# Warming up layer3.3.conv1...
# Running inference...
#
# Warming up layer3.3.conv2...
# Running inference...
#
# Warming up layer3.3.conv3...
# Running inference...
#
# Warming up layer3.4.conv1...
# Running inference...
#
# Warming up layer3.4.conv2...
# Running inference...
#
# Warming up layer3.4.conv3...
# Running inference...
#
# Warming up layer3.5.conv1...
# Running inference...
#
# Warming up layer3.5.conv2...
# Running inference...
#
# Warming up layer3.5.conv3...
# Running inference...
#
# Warming up layer4.0.conv1...
# Running inference...
#
# Warming up layer4.0.conv2...
# Running inference...
#
# Warming up layer4.0.conv3...
# Running inference...
#
# Warming up layer4.0.downsample.0...
# Running inference...
#
# Warming up layer4.1.conv1...
# Running inference...
#
# Warming up layer4.1.conv2...
# Running inference...
#
# Warming up layer4.1.conv3...
# Running inference...
#
# Warming up layer4.2.conv1...
# Running inference...
#
# Warming up layer4.2.conv2...
# Running inference...
#
# Warming up layer4.2.conv3...
# Running inference...
#
#   Protecting top-1 layers:
#     layer1.0.conv1  (F1 drop=0.9940)
#
# ============================================================
# RGP STEP 1/5 → target: 10%
# ============================================================
#   Computing DFOT scores (alpha=0.5)...
#   conv1: 64 → 29 filters
#     → updated layer1.0.conv1 input channels
#     → updated layer1.0.downsample.0 input channels
#   layer1.0.conv2: 64 → 47 filters
#     → updated layer1.0.conv3 input: → 47
#   layer1.1.conv2: 64 → 50 filters
#     → updated layer1.1.conv3 input: → 50
#   layer1.2.conv2: 64 → 49 filters
#     → updated layer1.2.conv3 input: → 49
#   layer1.2.conv1: 64 → 51 filters
#     → updated layer1.2.conv2 input: → 51
#   layer4.2.conv2: 512 → 420 filters
#     → updated layer4.2.conv3 input: → 420
#   layer3.1.conv2: 256 → 218 filters
#     → updated layer3.1.conv3 input: → 218
#   layer2.0.conv1: 128 → 105 filters
#     → updated layer2.0.conv2 input: → 105
#   layer4.1.conv2: 512 → 463 filters
#     → updated layer4.1.conv3 input: → 463
#   layer4.2.conv1: 512 → 445 filters
#     → updated layer4.2.conv2 input: → 445
#   layer2.1.conv1: 128 → 107 filters
#     → updated layer2.1.conv2 input: → 107
#   layer3.1.conv1: 256 → 214 filters
#     → updated layer3.1.conv2 input: → 214
#   layer2.0.conv2: 128 → 115 filters
#     → updated layer2.0.conv3 input: → 115
#   layer3.5.conv2: 256 → 236 filters
#     → updated layer3.5.conv3 input: → 236
#   layer2.2.conv2: 128 → 113 filters
#     → updated layer2.2.conv3 input: → 113
#   layer1.1.conv1: 64 → 52 filters
#     → updated layer1.1.conv2 input: → 52
#   layer3.2.conv2: 256 → 240 filters
#     → updated layer3.2.conv3 input: → 240
#   layer3.3.conv1: 256 → 246 filters
#     → updated layer3.3.conv2 input: → 246
#   layer3.2.conv1: 256 → 241 filters
#     → updated layer3.2.conv2 input: → 241
#   layer3.0.conv1: 256 → 229 filters
#     → updated layer3.0.conv2 input: → 229
#   layer2.3.conv2: 128 → 111 filters
#     → updated layer2.3.conv3 input: → 111
#   layer4.0.conv1: 512 → 479 filters
#     → updated layer4.0.conv2 input: → 479
#   layer4.0.conv2: 512 → 489 filters
#     → updated layer4.0.conv3 input: → 489
#   layer3.3.conv2: 256 → 241 filters
#     → updated layer3.3.conv3 input: → 241
#   layer4.1.conv1: 512 → 474 filters
#     → updated layer4.1.conv2 input: → 474
#   layer2.1.conv2: 128 → 120 filters
#     → updated layer2.1.conv3 input: → 120
#   layer3.4.conv2: 256 → 241 filters
#     → updated layer3.4.conv3 input: → 241
#   layer2.3.conv1: 128 → 112 filters
#     → updated layer2.3.conv2 input: → 112
#   layer3.0.conv2: 256 → 242 filters
#     → updated layer3.0.conv3 input: → 242
#   layer3.5.conv1: 256 → 250 filters
#     → updated layer3.5.conv2 input: → 250
#   layer2.2.conv1: 128 → 119 filters
#     → updated layer2.2.conv2 input: → 119
#   layer3.4.conv1: 256 → 249 filters
#     → updated layer3.4.conv2 input: → 249
#   Total filters removed: 755
#   Sparsity: 2.8%
# Epoch 1/1: 100%|██████████| 225/225 [00:34<00:00,  6.61batch/s, loss=0.00857]
# Validating: 100%|██████████| 57/57 [00:04<00:00, 12.79batch/s]
#   Epoch 1/1 | train_loss=0.2255 train_f1=0.9298 | val_loss=0.0185   val_f1=0.9941
#
# Warming up ResNet50_rgp_step1...
# Running inference...
#
#   ✓ F1=0.9941  Δ=-0.0018  size=79.9MB  latency=1.04ms  sparsity=2.8%
#   Saved → rgp_checkpoints/resnet50_rgp_step1_10pct/resnet50_rgp_step1_10pct.pth
#   Reassessing layer significance...
#
# === Layer Significance Assessment ===
#
# Warming up base...
# Running inference...
#   Baseline F1: 0.9941
# Significance scan:   0%|          | 0/53 [00:00<?, ?it/s]
# Warming up conv1...
# Running inference...
#
# Warming up layer1.0.conv1...
# Running inference...
#
# Warming up layer1.0.conv2...
# Running inference...
#
# Warming up layer1.0.conv3...
# Running inference...
#
# Warming up layer1.0.downsample.0...
# Running inference...
#
# Warming up layer1.1.conv1...
# Running inference...
#
# Warming up layer1.1.conv2...
# Running inference...
#
# Warming up layer1.1.conv3...
# Running inference...
#
# Warming up layer1.2.conv1...
# Running inference...
#
# Warming up layer1.2.conv2...
# Running inference...
#
# Warming up layer1.2.conv3...
# Running inference...
#
# Warming up layer2.0.conv1...
# Running inference...
#
# Warming up layer2.0.conv2...
# Running inference...
#
# Warming up layer2.0.conv3...
# Running inference...
#
# Warming up layer2.0.downsample.0...
# Running inference...
#
# Warming up layer2.1.conv1...
# Running inference...
#
# Warming up layer2.1.conv2...
# Running inference...
#
# Warming up layer2.1.conv3...
# Running inference...
#
# Warming up layer2.2.conv1...
# Running inference...
#
# Warming up layer2.2.conv2...
# Running inference...
#
# Warming up layer2.2.conv3...
# Running inference...
#
# Warming up layer2.3.conv1...
# Running inference...
#
# Warming up layer2.3.conv2...
# Running inference...
#
# Warming up layer2.3.conv3...
# Running inference...
#
# Warming up layer3.0.conv1...
# Running inference...
#
# Warming up layer3.0.conv2...
# Running inference...
#
# Warming up layer3.0.conv3...
# Running inference...
#
# Warming up layer3.0.downsample.0...
# Running inference...
#
# Warming up layer3.1.conv1...
# Running inference...
#
# Warming up layer3.1.conv2...
# Running inference...
#
# Warming up layer3.1.conv3...
# Running inference...
#
# Warming up layer3.2.conv1...
# Running inference...
#
# Warming up layer3.2.conv2...
# Running inference...
#
# Warming up layer3.2.conv3...
# Running inference...
#
# Warming up layer3.3.conv1...
# Running inference...
#
# Warming up layer3.3.conv2...
# Running inference...
#
# Warming up layer3.3.conv3...
# Running inference...
#
# Warming up layer3.4.conv1...
# Running inference...
#
# Warming up layer3.4.conv2...
# Running inference...
#
# Warming up layer3.4.conv3...
# Running inference...
#
# Warming up layer3.5.conv1...
# Running inference...
#
# Warming up layer3.5.conv2...
# Running inference...
#
# Warming up layer3.5.conv3...
# Running inference...
#
# Warming up layer4.0.conv1...
# Running inference...
#
# Warming up layer4.0.conv2...
# Running inference...
#
# Warming up layer4.0.conv3...
# Running inference...
# Epoch 1/1: 100%|██████████| 225/225 [00:29<00:00,  7.68batch/s, loss=0.00856]
# Validating: 100%|██████████| 57/57 [00:03<00:00, 14.87batch/s]
#   Epoch 1/1 | train_loss=0.0674 train_f1=0.9785 | val_loss=0.0043   val_f1=1.0000
#
# Warming up ResNet50_rgp_step4...
# Running inference...
#
#   ✓ F1=1.0000  Δ=+0.0041  size=55.4MB  latency=0.90ms  sparsity=2.0%
#   Saved → rgp_checkpoints/resnet50_rgp_step4_40pct/resnet50_rgp_step4_40pct.pth
#   Reassessing layer significance...
#
# === Layer Significance Assessment ===
#
# Warming up base...
# Running inference...
#   Baseline F1: 1.0000
# Significance scan:   0%|          | 0/53 [00:00<?, ?it/s]
# Warming up conv1...
# Running inference...
#
# Warming up layer1.0.conv1...
# Running inference...
#
# Warming up layer1.0.conv2...
# Running inference...
#
# Warming up layer1.0.conv3...
# Running inference...
#
# Warming up layer1.0.downsample.0...
# Running inference...
#
# Warming up layer1.1.conv1...
# Running inference...
#
# Warming up layer1.1.conv2...
# Running inference...
#
# Warming up layer1.1.conv3...
# Running inference...
#
# Warming up layer1.2.conv1...
# Running inference...
#
# Warming up layer1.2.conv2...
# Running inference...
#
# Warming up layer1.2.conv3...
# Running inference...
#
# Warming up layer2.0.conv1...
# Running inference...
#
# Warming up layer2.0.conv2...
# Running inference...
#
# Warming up layer2.0.conv3...
# Running inference...
#
# Warming up layer2.0.downsample.0...
# Running inference...
#
# Warming up layer2.1.conv1...
# Running inference...
#
# Warming up layer2.1.conv2...
# Running inference...
#
# Warming up layer2.1.conv3...
# Running inference...
#
# Warming up layer2.2.conv1...
# Running inference...
#
# Warming up layer2.2.conv2...
# Running inference...
#
# Warming up layer2.2.conv3...
# Running inference...
#
# Warming up layer2.3.conv1...
# Running inference...
#
# Warming up layer2.3.conv2...
# Running inference...
#
# Warming up layer2.3.conv3...
# Running inference...
#
# Warming up layer3.0.conv1...
# Running inference...
#
# Warming up layer3.0.conv2...
# Running inference...
#
# Warming up layer3.0.conv3...
# Running inference...
#
# Warming up layer3.0.downsample.0...
# Running inference...
#
# Warming up layer3.1.conv1...
# Running inference...
#
# Warming up layer3.1.conv2...
# Running inference...
#
# Warming up layer3.1.conv3...
# Running inference...
#
# Warming up layer3.2.conv1...
# Running inference...
#
# Warming up layer3.2.conv2...
# Running inference...
#
# Warming up layer3.2.conv3...
# Running inference...
#
# Warming up layer3.3.conv1...
# Running inference...
#
# Warming up layer3.3.conv2...
# Running inference...
#
# Warming up layer3.3.conv3...
# Running inference...
#
# Warming up layer3.4.conv1...
# Running inference...
#
# Warming up layer3.4.conv2...
# Running inference...
#
# Warming up layer3.4.conv3...
# Running inference...
#
# Warming up layer3.5.conv1...
# Running inference...
#
# Warming up layer3.5.conv2...
# Running inference...
#
# Warming up layer3.5.conv3...
# Running inference...
#
# Warming up layer4.0.conv1...
# Running inference...
#
# Warming up layer4.0.conv2...
# Running inference...
#
# Warming up layer4.0.conv3...
# Running inference...
#
# Warming up layer4.0.downsample.0...
# Running inference...
#
# Warming up layer4.1.conv1...
# Running inference...
#
# Warming up layer4.1.conv2...
# Running inference...
#
# Warming up layer4.1.conv3...
# Running inference...
#
# Warming up layer4.2.conv1...
# Running inference...
#
# Warming up layer4.2.conv2...
# Running inference...
#
# Warming up layer4.2.conv3...
# Running inference...
#
#   Protecting top-1 layers:
#     conv1  (F1 drop=0.9996)
#
# ============================================================
# RGP STEP 5/5 → target: 50%
# ============================================================
#   Computing DFOT scores (alpha=0.5)...
#   layer4.0.conv2: 384 → 333 filters
#     → updated layer4.0.conv3 input: → 333
#   layer4.2.conv2: 237 → 203 filters
#     → updated layer4.2.conv3 input: → 203
#   layer4.1.conv2: 289 → 245 filters
#     → updated layer4.1.conv3 input: → 245
#   layer4.2.conv1: 274 → 234 filters
#     → updated layer4.2.conv2 input: → 234
#   layer3.4.conv2: 198 → 183 filters
#     → updated layer3.4.conv3 input: → 183
#   layer1.0.conv2: 29 → 24 filters
#     → updated layer1.0.conv3 input: → 24
#   layer3.2.conv2: 189 → 177 filters
#     → updated layer3.2.conv3 input: → 177
#   layer1.1.conv2: 30 → 23 filters
#     → updated layer1.1.conv3 input: → 23
#   layer1.1.conv1: 31 → 25 filters
#     → updated layer1.1.conv2 input: → 25
#   layer4.1.conv1: 363 → 332 filters
#     → updated layer4.1.conv2 input: → 332
#   layer2.0.conv1: 82 → 73 filters
#     → updated layer2.0.conv2 input: → 73
#   layer2.1.conv1: 69 → 64 filters
#     → updated layer2.1.conv2 input: → 64
#   layer2.2.conv2: 91 → 81 filters
#     → updated layer2.2.conv3 input: → 81
#   layer3.3.conv2: 205 → 190 filters
#     → updated layer3.3.conv3 input: → 190
#   layer3.1.conv2: 161 → 148 filters
#     → updated layer3.1.conv3 input: → 148
#   layer4.0.conv1: 379 → 352 filters
#     → updated layer4.0.conv2 input: → 352
#   layer2.1.conv2: 92 → 85 filters
#     → updated layer2.1.conv3 input: → 85
#   layer3.1.conv1: 153 → 143 filters
#     → updated layer3.1.conv2 input: → 143
#   layer3.5.conv2: 183 → 165 filters
#     → updated layer3.5.conv3 input: → 165
#   layer3.4.conv1: 217 → 205 filters
#     → updated layer3.4.conv2 input: → 205
#   layer2.3.conv1: 91 → 84 filters
#     → updated layer2.3.conv2 input: → 84
#   layer3.0.conv2: 214 → 205 filters
#     → updated layer3.0.conv3 input: → 205
#   layer2.2.conv1: 97 → 93 filters
#     → updated layer2.2.conv2 input: → 93
#   layer3.3.conv1: 213 → 200 filters
#     → updated layer3.3.conv2 input: → 200
#   layer3.5.conv1: 210 → 193 filters
#     → updated layer3.5.conv2 input: → 193
#   layer3.2.conv1: 206 → 194 filters
#     → updated layer3.2.conv2 input: → 194
#   layer3.0.conv1: 178 → 164 filters
#     → updated layer3.0.conv2 input: → 164
#   layer2.3.conv2: 80 → 70 filters
#     → updated layer2.3.conv3 input: → 70
#   layer2.0.conv2: 96 → 93 filters
#     → updated layer2.0.conv3 input: → 93
#   layer1.0.conv1: 32 → 29 filters
#     → updated layer1.0.conv2 input: → 29
#   layer1.2.conv1: 30 → 28 filters
#     → updated layer1.2.conv2 input: → 28
#   layer1.2.conv2: 33 → 31 filters
#     → updated layer1.2.conv3 input: → 31
#   Total filters removed: 471
#   Sparsity: 1.8%
# Epoch 1/1: 100%|██████████| 225/225 [00:28<00:00,  7.83batch/s, loss=0.0307]
# Validating: 100%|██████████| 57/57 [00:03<00:00, 14.92batch/s]
#   Epoch 1/1 | train_loss=0.0561 train_f1=0.9857 | val_loss=0.0116   val_f1=0.9905
#
# Warming up ResNet50_rgp_step5...
# Running inference...
#
#   ✓ F1=0.9905  Δ=-0.0054  size=49.4MB  latency=0.89ms  sparsity=1.8%
#   Saved → rgp_checkpoints/resnet50_rgp_step5_50pct/resnet50_rgp_step5_50pct.pth
#   Reassessing layer significance...
#
# === Layer Significance Assessment ===
#
# Warming up base...
# Running inference...
#   Baseline F1: 0.9905
# Significance scan:   0%|          | 0/53 [00:00<?, ?it/s]
# Warming up conv1...
# Running inference...
#
# Warming up layer1.0.conv1...
# Running inference...
#
# Warming up layer1.0.conv2...
# Running inference...
#
# Warming up layer1.0.conv3...
# Running inference...
#
# Warming up layer1.0.downsample.0...
# Running inference...
#
# Warming up layer1.1.conv1...
# Running inference...
#
# Warming up layer1.1.conv2...
# Running inference...
#
# Warming up layer1.1.conv3...
# Running inference...
#
# Warming up layer1.2.conv1...
# Running inference...
#
# Warming up layer1.2.conv2...
# Running inference...
#
# Warming up layer1.2.conv3...
# Running inference...
#
# Warming up layer2.0.conv1...
# Running inference...
#
# Warming up layer2.0.conv2...
# Running inference...
#
# Warming up layer2.0.conv3...
# Running inference...
#
# Warming up layer2.0.downsample.0...
# Running inference...
#
# Warming up layer2.1.conv1...
# Running inference...
#
# Warming up layer2.1.conv2...
# Running inference...
#
# Warming up layer2.1.conv3...
# Running inference...
#
# Warming up layer2.2.conv1...
# Running inference...
#
# Warming up layer2.2.conv2...
# Running inference...
#
# Warming up layer2.2.conv3...
# Running inference...
#
# Warming up layer2.3.conv1...
# Running inference...
#
# Warming up layer2.3.conv2...
# Running inference...
#
# Warming up layer2.3.conv3...
# Running inference...
#
# Warming up layer3.0.conv1...
# Running inference...
#
# Warming up layer3.0.conv2...
# Running inference...
#
# Warming up layer3.0.conv3...
# Running inference...
#
# Warming up layer3.0.downsample.0...
# Running inference...
#
# Warming up layer3.1.conv1...
# Running inference...
#
# Warming up layer3.1.conv2...
# Running inference...
#
# Warming up layer3.1.conv3...
# Running inference...
#
# Warming up layer3.2.conv1...
# Running inference...
#
# Warming up layer3.2.conv2...
# Running inference...
#
# Warming up layer3.2.conv3...
# Running inference...
#
# Warming up layer3.3.conv1...
# Running inference...
#
# Warming up layer3.3.conv2...
# Running inference...
#
# Warming up layer3.3.conv3...
# Running inference...
#
# Warming up layer3.4.conv1...
# Running inference...
#
# Warming up layer3.4.conv2...
# Running inference...
#
# Warming up layer3.4.conv3...
# Running inference...
#
# Warming up layer3.5.conv1...
# Running inference...
#
# Warming up layer3.5.conv2...
# Running inference...
#
# Warming up layer3.5.conv3...
# Running inference...
#
# Warming up layer4.0.conv1...
# Running inference...
#
# Warming up layer4.0.conv2...
# Running inference...
#
# Warming up layer4.0.conv3...
# Running inference...
#
# Warming up layer4.0.downsample.0...
# Running inference...
#
# Warming up layer4.1.conv1...
# Running inference...
#
# Warming up layer4.1.conv2...
# Running inference...
#
# Warming up layer4.1.conv3...
# Running inference...
#
# Warming up layer4.2.conv1...
# Running inference...
#
# Warming up layer4.2.conv2...
# Running inference...
#
# Warming up layer4.2.conv3...
# Running inference...
#
#   Protecting top-1 layers:
#     conv1  (F1 drop=0.9901)
#
# ============================================================
# RGP COMPLETE
#  step  target_ratio  sparsity  f1_macro  f1_micro  sensitivity   f1_drop  latency_ms   size_mb
#     1           0.1  0.028495  0.994099  0.994444     0.992880  0.001782    1.037509 79.871681
#     2           0.2  0.024721  0.973518  0.973889     0.972231  0.022363    0.982579 70.279587
#     3           0.3  0.021362  0.996503  0.997778     0.997234 -0.000622    0.920956 62.266651
#     4           0.4  0.019550  1.000000  1.000000     1.000000 -0.004119    0.896917 55.355038
#     5           0.5  0.017776  0.990508  0.997778     0.991736  0.005373    0.885377 49.358540
# ============================================================
#
# =================================================================
# =================================================================
# +--------------------+------------+---------------------+-------------------+
# | Model              |   F1 Macro |   cuda Latency (ms) |   Model Size (mb) |
# +====================+============+=====================+===================+
# | ResNet50_baseline  |       1    |                1.1  |             90.83 |
# +--------------------+------------+---------------------+-------------------+
# | ResNet50_rgp_step1 |       0.99 |                1.04 |             79.87 |
# +--------------------+------------+---------------------+-------------------+
# | ResNet50_rgp_step2 |       0.97 |                0.98 |             70.28 |
# +--------------------+------------+---------------------+-------------------+
# | ResNet50_rgp_step3 |       1    |                0.92 |             62.27 |
# +--------------------+------------+---------------------+-------------------+
# | ResNet50_rgp_step4 |       1    |                0.9  |             55.36 |
# +--------------------+------------+---------------------+-------------------+
# | ResNet50_rgp_step5 |       0.99 |                0.89 |             49.36 |
# +--------------------+------------+---------------------+-------------------+

# %%
#visulaise
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(16, 4))

axes[0].plot(log_df["sparsity"]*100, log_df["f1_macro"], "o-", color="steelblue", lw=2)
axes[0].axhline(BASELINE_F1, color="red", linestyle="--", label=f"Baseline ({BASELINE_F1:.3f})")
axes[0].set_xlabel("Sparsity (%)"); axes[0].set_ylabel("F1 Macro")
axes[0].set_title("RGP: F1 vs Sparsity"); axes[0].legend(); axes[0].grid(True, alpha=0.3)

axes[1].plot(log_df["sparsity"]*100, log_df["latency_ms"], "s-", color="green", lw=2)
axes[1].set_xlabel("Sparsity (%)"); axes[1].set_ylabel("Latency (ms/sample)")
axes[1].set_title("RGP: Latency vs Sparsity"); axes[1].grid(True, alpha=0.3)

axes[2].bar(log_df["step"], log_df["f1_drop"], color="salmon", edgecolor="darkred")
axes[2].set_xlabel("Step"); axes[2].set_ylabel("F1 Drop")
axes[2].set_title("RGP: F1 Drop per Step"); axes[2].grid(True, alpha=0.3, axis="y")

plt.tight_layout()
plt.savefig("rgp_checkpoints/rgp_results.png", dpi=150)
plt.show()
print("Saved → rgp_checkpoints/rgp_results.png")
print("Import rgp_checkpoints/rgp_log.csv in graphing.ipynb for combined plots")
# Out:
# Saved → rgp_checkpoints/rgp_results.png
# Import rgp_checkpoints/rgp_log.csv in graphing.ipynb for combined plots
