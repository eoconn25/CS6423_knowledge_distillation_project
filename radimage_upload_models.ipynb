# %%
import os

target_folder = "CS6423_knowledge_distillation_project" 
path = os.path.join(os.getcwd(), target_folder)

if not os.getgetcwd().endswith(target_folder):
    os.chdir(path)

# should match the folder you cloned into
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: /home/kod6/CS6423_knowledge_distillation_project

# %%
from huggingface_hub import login, HfApi


login("hf_your_token_here")      # must be write token with permissions to write to kd-proj-cs6423/cs6423_model_repo

api = HfApi()

api.upload_folder(
    folder_path="trained_models/",
    repo_id="kd-proj-cs6423/cs6423_model_repo",
    repo_type="model",
    ignore_patterns=["*.md"]
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# CommitInfo(commit_url='https://huggingface.co/fiabar/cs6423_model_repo/commit/f0b1fd06d8e757830e8f90c01fce80b625038849', commit_message='Upload folder using huggingface_hub', commit_description='', oid='f0b1fd06d8e757830e8f90c01fce80b625038849', pr_url=None, repo_url=RepoUrl('https://huggingface.co/fiabar/cs6423_model_repo', endpoint='https://huggingface.co', repo_type='model', repo_id='fiabar/cs6423_model_repo'), pr_revision=None, pr_num=None)

# %%
import os
for root, dirs, files in os.walk('trained_models'):
    for f in files:
        if 'rgp_step' in f:
            print(os.path.join(root, f))
# Out:
# trained_models/rgp_step_0.1/rgp_step_0.1.pth
# trained_models/rgp_step_0.1/rgp_step_0.1_full.pth
# trained_models/rgp_step_0.2/rgp_step_0.2.pth
# trained_models/rgp_step_0.2/rgp_step_0.2_full.pth
# trained_models/rgp_step_0.3/rgp_step_0.3.pth
# trained_models/rgp_step_0.3/rgp_step_0.3_full.pth
# trained_models/rgp_step_0.4/rgp_step_0.4.pth
# trained_models/rgp_step_0.4/rgp_step_0.4_full.pth
# trained_models/rgp_step_0.5/rgp_step_0.5.pth
# trained_models/rgp_step_0.5/rgp_step_0.5_full.pth
